# %% [markdown]
# **Testing 101 - First Lab Activity**
#
# Macasasa, Dorothy V. (2024)
#
# *Note: This is Lab Activity 1 & 2*

# %%
# Example
import time
print (time.ctime())
# Out:
# Fri Feb  2 04:46:35 2024

# %%
time.sleep(5)
print(time.ctime())
# Out:
# Fri Feb  2 04:46:43 2024

# %% [markdown]
# **This my Python notebook**
#
# *This*
#
# ~This~
#
#
# **MARKDOWN**

# %%
# Printing Hello World
print("This is Dorothy Macasasa, real last name HO. Nice to meet you!")
# Out:
# This is Dorothy Macasasa, real last name HO. Nice to meet you!

# %%
print('Hello, world!!!!!!!')
# Out:
# Hello, world!!!!!!!

# %%
# printing a number (string)
print('3')
# Out:
# 3

# %%
x = 9
print (x)
x=18
# Out:
# 9

# %%
x = 15
print (x+30)
# Out:
# 45

# %%
#setting Variable to numbers only otherwise it will not work (Sample Scenario)
D = Dorothy
print(D)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-71a4d4d0edea> in <cell line: 2>()
#       1 #setting Variable to numbers only otherwise it will not work (Sample Scenario)
# ----> 2 D = Dorothy
#       3 print(D)
#
# NameError: name 'Dorothy' is not defined

# %%
# Setting another sample parameters
print(2*x+40)
# Out:
# 70

# %%
# Setting other parameter (x) and correlate it to first parameter (x)
y = x/2
print (2*y)
# Out:
# 15.0

# %% [markdown]
# **Python 2nd Activity Arithmetic**

# %%
x = int(input("X:"))
# Out:
# X:7

# %%
y = int(input("Y:"))
# Out:
# Y:9

# %%
sum = x +y
print ("Sum:")
x + y
# Out:
# Sum:
# 16

# %%
product = x*y
print ("Product:")
x * y
# Out:
# Product:
# 63

# %%
print("Product:", product)
# Out:
# Product: 63

# %%
print("Sum:", sum)
print("Product:", product)
# Out:
# Sum: 16
# Product: 63

# %%
# using exponents
growth = x**y
print("Growth Yeild:",growth)
# Out:
# Growth Yeild: 40353607

# %%
annuity = sum**product
print ("Annuity:", annuity)
# Out:
# Annuity: 7237005577332262213973186563042994240829374041602535252466099000494570602496

# %% [markdown]
# **Import Math library**

# %%
import math

# %%
math.log(35, 78)
# Out:
# 0.8160628132201606

# %%
round(4576876.0778690, 4)
# Out:
# 4576876.0779

# %%
x = 15
y = 4

x/y
# Out:
# 3.75

# %%
round(x/y,1)
# Out:
# 3.8

# %%
div = x/y
rn=round (div)
rnd=round (div , 1)
rnd2=round (div , 2)


print("Div:", div)
print("Round to whole", rn)
print("Round to 1 decimal point", rnd)
print("Round to 2 decimal point", rnd2)
# Out:
# Div: 3.75
# Round to whole 4
# Round to 1 decimal point 3.8
# Round to 2 decimal point 3.75

# %%
# Macasasa, Dorothy V.
