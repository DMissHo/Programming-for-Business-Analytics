# %% [markdown]
# **Python Variable**

# %%
x = 20
y ="Python is fun"
z = 144**0.5 == 12
print(x)
print(y)
print(z)
# Out:
# 20
# Python is fun
# True

# %%
# it reads the code if it has it's own command prompt, otherwise it will return the latest one
p = 8
print(p)

p = 10
print(p)
# Out:
# 8
# 10

# %%
# Exploring commands without direct prompt it is reads
x + y + z
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-b5bd3aae62b8> in <cell line: 1>()
# ----> 1 x + y + z
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
# Exploring commands without direct prompt it is reads
x = 20
#y ="Python is fun"
y = 1
z = 144**0.5 == 12

# %%
x + y + z
# Out:
# 22

# %%
x = 20
y ="Python is fun"
z = 144**0.5 == 12
print(x)
print(y)
print("Answer:", str(x+y))
# trying direct variable if it will neglect the rule subject to str() that can be only used to number
# Out:
# 20
# Python is fun
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-2a923f6d47d2> in <cell line: 6>()
#       4 print(x)
#       5 print(y)
# ----> 6 print("Answer:", str(x+y))
#       7 # trying direct variable if it will neglect the rule subject to str() that can be only used to number
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %% [markdown]
# **Setting Variables**

# %%
n = m= 4
x= y=3
x = n
y=m
print(n)
print(m)
print(m*n)
print(x)
print(y)
print(x*y)
# Out:
# 4
# 4
# 16
# 4
# 4
# 16

# %%
k, l, m = (20, 30, 50)

print(k)
print(l)
print(m)

k=  38
l=48
m = 58
print(k)
print(l)
print(m)
# Out:
# 20
# 30
# 50
# 38
# 48
# 58

# %%
x = 10
y =5

(x,y)=(y,x)
print(x)
# Out:
# 5

# %% [markdown]
# **Macasasa, Dorothy V. (2024)**
