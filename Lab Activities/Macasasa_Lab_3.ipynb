# %% [markdown]
# **Lab Activity 3**
#
# Macasasa, Dorothy (2024)

# %%
# number vs float number
print("Number:", int(134.43453))
# Out:
# Number: 134

# %%
print("Float Number:", float(134.43453)) # float number
# Out:
# Float Number: 134.43453

# %%
# Boolean Execution
x = 190
y = 200
Statement = x > y
print("Boolean:", Statement)
# Out:
# Boolean: False

# %%
print("String:", str(7))
# Out:
# String: 7

# %%
print("String:", str(Statement))
# Out:
# String: False

# %%
# define a function that prints the input but returns nothing?

def my_function(x):
  print(x)
  print(y)

my_function("hello") == None
# Out:
# hello
# 200
# True

# %%
# Macasasa, Dorothy V. (2024)
